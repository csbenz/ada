# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.
DATA_FOLDER = 'Data' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average* per year of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %%
# Write your answer here

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
# Read the metadata
folderPath = DATA_FOLDER + '/microbiome'
metaRaw = pd.read_excel((folderPath + '/metadata.xls'), sheetname='Sheet1', index_col=0)

# %%
#Change the NaN value to unknown
meta = metaRaw.fillna('unknown')
meta
# Out:
#                       GROUP   SAMPLE
# BARCODE
# MID1     EXTRACTION CONTROL  unknown
# MID2                  NEC 1   tissue
# MID3              Control 1   tissue
# MID4                  NEC 2   tissue
# MID5              Control 2   tissue
# MID6                  NEC 1    stool
# MID7              Control 1    stool
# MID8                  NEC 2    stool
# MID9              Control 2    stool

# %%
# Read the each data spreadsheet
md1Raw = pd.read_excel((folderPath + '/MID1.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md1 = md1Raw.fillna('unknown')
md1.head()
md1.shape
# Out:
# (272, 2)

# %%
md2Raw = pd.read_excel((folderPath + '/MID2.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md2 = md2Raw.fillna('unknown')
md2.head()
md2.shape
# Out:
# (288, 2)

# %%
md3Raw = pd.read_excel((folderPath + '/MID3.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md3 = md3Raw.fillna('unknown')
md3.head()
md3.shape
# Out:
# (367, 2)

# %%
md4Raw = pd.read_excel((folderPath + '/MID4.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md4 = md4Raw.fillna('unknown')
md4.head()
md4.shape
# Out:
# (134, 2)

# %%
md5Raw = pd.read_excel((folderPath + '/MID5.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md5 = md5Raw.fillna('unknown')
md5.head()
md5.shape
# Out:
# (379, 2)

# %%
md6Raw = pd.read_excel((folderPath + '/MID6.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md6 = md6Raw.fillna('unknown')
md6.head()
md6.shape
# Out:
# (181, 2)

# %%
md7Raw = pd.read_excel((folderPath + '/MID7.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md7 = md7Raw.fillna('unknown')
md7.head()
md7.shape
# Out:
# (395, 2)

# %%
md8Raw = pd.read_excel((folderPath + '/MID8.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md8 = md8Raw.fillna('unknown')
md8.head()
md8.shape
# Out:
# (99, 2)

# %%
md9Raw = pd.read_excel((folderPath + '/MID9.xls'), sheetname='Sheet 1', header=None)
#Change the NaN value to unknown
md9 = md9Raw.fillna('unknown')
md9.head()
md9.shape
# Out:
# (281, 2)

# %%
md1.columns = md2.columns = md3.columns = md4.columns = md5.columns = md6.columns = md7.columns = md8.columns = md9.columns = ['Taxon', 'Count']

#Add Group column (Adding them one by one is easier)
md1['Group'] = meta.GROUP['MID1']
md2['Group'] = meta.GROUP['MID2']
md3['Group'] = meta.GROUP['MID3']
md4['Group'] = meta.GROUP['MID4']
md5['Group'] = meta.GROUP['MID5']
md6['Group'] = meta.GROUP['MID6']
md7['Group'] = meta.GROUP['MID7']
md8['Group'] = meta.GROUP['MID8']
md9['Group'] = meta.GROUP['MID9']
#Add Sample
md1['Sample'] = meta.SAMPLE['MID1']
md2['Sample'] = meta.SAMPLE['MID2']
md3['Sample'] = meta.SAMPLE['MID3']
md4['Sample'] = meta.SAMPLE['MID4']
md5['Sample'] = meta.SAMPLE['MID5']
md6['Sample'] = meta.SAMPLE['MID6']
md7['Sample'] = meta.SAMPLE['MID7']
md8['Sample'] = meta.SAMPLE['MID8']
md9['Sample'] = meta.SAMPLE['MID9']
#Concatenate everything into one DataFrame
md = pd.concat([md1, md2, md3, md4, md5, md6, md7, md8, md9], axis=0)
md
# Out:
#                                                  Taxon  Count  \
# 0    Archaea "Crenarchaeota" Thermoprotei Desulfuro...      7
# 1    Archaea "Crenarchaeota" Thermoprotei Desulfuro...      2
# 2    Archaea "Crenarchaeota" Thermoprotei Sulfoloba...      3
# 3    Archaea "Crenarchaeota" Thermoprotei Thermopro...      3
# 4    Archaea "Euryarchaeota" "Methanomicrobia" Meth...      7
# 5    Archaea "Euryarchaeota" "Methanomicrobia" Meth...      1
# 6    Archaea "Euryarchaeota" "Methanomicrobia" Meth...      1
# 7    Archaea "Euryarchaeota" Archaeoglobi Archaeogl...      1
# 8    Archaea "Euryarchaeota" Archaeoglobi Archaeogl...      1
# 9    Archaea "Euryarchaeota" Halobacteria Halobacte...      1
# 10   Archaea "Euryarchaeota" Halobacteria Halobacte...      4
# 11   Archaea "Euryarchaeota" Halobacteria Halobacte...      1
# 12   Archaea "Euryarchaeota" Halobacteria Halobacte...      2
# 13   Archaea "Euryarchaeota" Halobacteria Halobacte...      4
# 14   Archaea "Euryarchaeota" Methanococci Methanoco...      1
# 15   Archaea "Euryarchaeota" Methanopyri Methanopyr...     12
# 16   Archaea "Euryarchaeota" Thermoplasmata Thermop...      2
# 17   Bacteria "Actinobacteria" Actinobacteria Actin...      2
# 18   Bacteria "Actinobacteria" Actinobacteria Actin...      1
# 19   Bacteria "Actinobacteria" Actinobacteria Actin...      1
# 20   Bacteria "Actinobacteria" Actinobacteria Actin...      1
# 21   Bacteria "Actinobacteria" Actinobacteria Actin...      2
# 22   Bacteria "Actinobacteria" Actinobacteria Actin...     53
# 23   Bacteria "Actinobacteria" Actinobacteria Actin...      1
# 24   Bacteria "Actinobacteria" Actinobacteria Actin...      2
# 25   Bacteria "Actinobacteria" Actinobacteria Actin...      3
# 26   Bacteria "Actinobacteria" Actinobacteria Actin...      1
# 27   Bacteria "Actinobacteria" Actinobacteria Actin...     99
# 28   Bacteria "Actinobacteria" Actinobacteria Actin...     17
# 29   Bacteria "Actinobacteria" Actinobacteria Actin...      2
# ..                                                 ...    ...
# 251  Bacteria "Proteobacteria" Gammaproteobacteria ...     10
# 252  Bacteria "Proteobacteria" Gammaproteobacteria ...      1
# 253  Bacteria "Proteobacteria" Gammaproteobacteria ...      1
# 254  Bacteria "Proteobacteria" Gammaproteobacteria ...      1
# 255  Bacteria "Proteobacteria" Gammaproteobacteria ...     12
# 256  Bacteria "Proteobacteria" Gammaproteobacteria ...      4
# 257  Bacteria "Proteobacteria" Gammaproteobacteria ...    805
# 258  Bacteria "Proteobacteria" Gammaproteobacteria ...    862
# 259  Bacteria "Proteobacteria" Gammaproteobacteria ...     12
# 260  Bacteria "Proteobacteria" Gammaproteobacteria ...   3534
# 261  Bacteria "Proteobacteria" Gammaproteobacteria ...      4
# 262  Bacteria "Proteobacteria" Gammaproteobacteria ...      1
# 263  Bacteria "Proteobacteria" Gammaproteobacteria ...     25
# 264  Bacteria "Proteobacteria" Gammaproteobacteria ...      2
# 265  Bacteria "Proteobacteria" Gammaproteobacteria ...      3
# 266  Bacteria "Proteobacteria" Gammaproteobacteria ...      2
# 267  Bacteria "Proteobacteria" Gammaproteobacteria ...      1
# 268  Bacteria "Proteobacteria" Gammaproteobacteria ...      3
# 269  Bacteria "Proteobacteria" Gammaproteobacteria ...      2
# 270  Bacteria "Proteobacteria" Gammaproteobacteria ...      1
# 271  Bacteria "Synergistetes" Synergistia Synergist...      3
# 272  Bacteria "Tenericutes" Mollicutes Anaeroplasma...      1
# 273  Bacteria "Tenericutes" Mollicutes Haloplasmata...     11
# 274  Bacteria "Thermodesulfobacteria" Thermodesulfo...      1
# 275  Bacteria "Thermodesulfobacteria" Thermodesulfo...      1
# 276  Bacteria "Thermotogae" Thermotogae Thermotogal...     43
# 277  Bacteria "Thermotogae" Thermotogae Thermotogal...     16
# 278  Bacteria "Verrucomicrobia" Opitutae Opitutales...      1
# 279  Bacteria Cyanobacteria Cyanobacteria  Chloropl...      1
# 280  Bacteria Cyanobacteria Cyanobacteria  Chloropl...     10
#
#                   Group   Sample
# 0    EXTRACTION CONTROL  unknown
# 1    EXTRACTION CONTROL  unknown
# 2    EXTRACTION CONTROL  unknown
# 3    EXTRACTION CONTROL  unknown
# 4    EXTRACTION CONTROL  unknown
# 5    EXTRACTION CONTROL  unknown
# 6    EXTRACTION CONTROL  unknown
# 7    EXTRACTION CONTROL  unknown
# 8    EXTRACTION CONTROL  unknown
# 9    EXTRACTION CONTROL  unknown
# 10   EXTRACTION CONTROL  unknown
# 11   EXTRACTION CONTROL  unknown
# 12   EXTRACTION CONTROL  unknown
# 13   EXTRACTION CONTROL  unknown
# 14   EXTRACTION CONTROL  unknown
# 15   EXTRACTION CONTROL  unknown
# 16   EXTRACTION CONTROL  unknown
# 17   EXTRACTION CONTROL  unknown
# 18   EXTRACTION CONTROL  unknown
# 19   EXTRACTION CONTROL  unknown
# 20   EXTRACTION CONTROL  unknown
# 21   EXTRACTION CONTROL  unknown
# 22   EXTRACTION CONTROL  unknown
# 23   EXTRACTION CONTROL  unknown
# 24   EXTRACTION CONTROL  unknown
# 25   EXTRACTION CONTROL  unknown
# 26   EXTRACTION CONTROL  unknown
# 27   EXTRACTION CONTROL  unknown
# 28   EXTRACTION CONTROL  unknown
# 29   EXTRACTION CONTROL  unknown
# ..                  ...      ...
# 251           Control 2    stool
# 252           Control 2    stool
# 253           Control 2    stool
# 254           Control 2    stool
# 255           Control 2    stool
# 256           Control 2    stool
# 257           Control 2    stool
# 258           Control 2    stool
# 259           Control 2    stool
# 260           Control 2    stool
# 261           Control 2    stool
# 262           Control 2    stool
# 263           Control 2    stool
# 264           Control 2    stool
# 265           Control 2    stool
# 266           Control 2    stool
# 267           Control 2    stool
# 268           Control 2    stool
# 269           Control 2    stool
# 270           Control 2    stool
# 271           Control 2    stool
# 272           Control 2    stool
# 273           Control 2    stool
# 274           Control 2    stool
# 275           Control 2    stool
# 276           Control 2    stool
# 277           Control 2    stool
# 278           Control 2    stool
# 279           Control 2    stool
# 280           Control 2    stool
#
# [2396 rows x 4 columns]

# %%
#Hierarchical Index Name, Group, Sample to account for the Bacterias overlap and keep the index unique
mdIndexed = md.set_index(['Taxon', 'Group', 'Sample'])
mdIndexed
# Out:
#                                                                                Count
# Taxon                                              Group              Sample
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc... EXTRACTION CONTROL unknown      7
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc... EXTRACTION CONTROL unknown      2
# Archaea "Crenarchaeota" Thermoprotei Sulfolobal... EXTRACTION CONTROL unknown      3
# Archaea "Crenarchaeota" Thermoprotei Thermoprot... EXTRACTION CONTROL unknown      3
# Archaea "Euryarchaeota" "Methanomicrobia" Metha... EXTRACTION CONTROL unknown      7
# Archaea "Euryarchaeota" "Methanomicrobia" Metha... EXTRACTION CONTROL unknown      1
# Archaea "Euryarchaeota" "Methanomicrobia" Metha... EXTRACTION CONTROL unknown      1
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo... EXTRACTION CONTROL unknown      1
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo... EXTRACTION CONTROL unknown      1
# Archaea "Euryarchaeota" Halobacteria Halobacter... EXTRACTION CONTROL unknown      1
# Archaea "Euryarchaeota" Halobacteria Halobacter... EXTRACTION CONTROL unknown      4
# Archaea "Euryarchaeota" Halobacteria Halobacter... EXTRACTION CONTROL unknown      1
# Archaea "Euryarchaeota" Halobacteria Halobacter... EXTRACTION CONTROL unknown      2
# Archaea "Euryarchaeota" Halobacteria Halobacter... EXTRACTION CONTROL unknown      4
# Archaea "Euryarchaeota" Methanococci Methanococ... EXTRACTION CONTROL unknown      1
# Archaea "Euryarchaeota" Methanopyri Methanopyra... EXTRACTION CONTROL unknown     12
# Archaea "Euryarchaeota" Thermoplasmata Thermopl... EXTRACTION CONTROL unknown      2
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      2
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      1
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      1
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      1
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      2
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown     53
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      1
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      2
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      3
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      1
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown     99
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown     17
# Bacteria "Actinobacteria" Actinobacteria Actino... EXTRACTION CONTROL unknown      2
# ...                                                                              ...
# Bacteria "Proteobacteria" Gammaproteobacteria O... Control 2          stool       10
# Bacteria "Proteobacteria" Gammaproteobacteria O... Control 2          stool        1
# Bacteria "Proteobacteria" Gammaproteobacteria O... Control 2          stool        1
# Bacteria "Proteobacteria" Gammaproteobacteria P... Control 2          stool        1
# Bacteria "Proteobacteria" Gammaproteobacteria P... Control 2          stool       12
# Bacteria "Proteobacteria" Gammaproteobacteria P... Control 2          stool        4
# Bacteria "Proteobacteria" Gammaproteobacteria P... Control 2          stool      805
# Bacteria "Proteobacteria" Gammaproteobacteria P... Control 2          stool      862
# Bacteria "Proteobacteria" Gammaproteobacteria P... Control 2          stool       12
# Bacteria "Proteobacteria" Gammaproteobacteria P... Control 2          stool     3534
# Bacteria "Proteobacteria" Gammaproteobacteria T... Control 2          stool        4
# Bacteria "Proteobacteria" Gammaproteobacteria T... Control 2          stool        1
# Bacteria "Proteobacteria" Gammaproteobacteria T... Control 2          stool       25
# Bacteria "Proteobacteria" Gammaproteobacteria T... Control 2          stool        2
# Bacteria "Proteobacteria" Gammaproteobacteria X... Control 2          stool        3
# Bacteria "Proteobacteria" Gammaproteobacteria X... Control 2          stool        2
# Bacteria "Proteobacteria" Gammaproteobacteria X... Control 2          stool        1
# Bacteria "Proteobacteria" Gammaproteobacteria X... Control 2          stool        3
# Bacteria "Proteobacteria" Gammaproteobacteria X... Control 2          stool        2
# Bacteria "Proteobacteria" Gammaproteobacteria X... Control 2          stool        1
# Bacteria "Synergistetes" Synergistia Synergista... Control 2          stool        3
# Bacteria "Tenericutes" Mollicutes Anaeroplasmat... Control 2          stool        1
# Bacteria "Tenericutes" Mollicutes Haloplasmatal... Control 2          stool       11
# Bacteria "Thermodesulfobacteria" Thermodesulfob... Control 2          stool        1
# Bacteria "Thermodesulfobacteria" Thermodesulfob... Control 2          stool        1
# Bacteria "Thermotogae" Thermotogae Thermotogale... Control 2          stool       43
# Bacteria "Thermotogae" Thermotogae Thermotogale... Control 2          stool       16
# Bacteria "Verrucomicrobia" Opitutae Opitutales ... Control 2          stool        1
# Bacteria Cyanobacteria Cyanobacteria  Chloropla... Control 2          stool        1
# Bacteria Cyanobacteria Cyanobacteria  Chloropla... Control 2          stool       10
#
# [2396 rows x 1 columns]

# %%
mdIndexed.index.is_unique
# Out:
# True

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')

# %% [markdown]
# For each of the following questions state clearly your assumptions and discuss your findings:
# 1. Describe the *type* and the *value range* of each attribute. Indicate and transform the attributes that can be `Categorical`.
# 2. Plot histograms for the *travel class*, *embarkation port*, *sex* and *age* attributes. For the latter one, use *discrete decade intervals*.
# 3. Calculate the proportion of passengers by *cabin floor*. Present your results in a *pie chart*.
# 4. For each *travel class*, calculate the proportion of the passengers that survived. Present your results in *pie charts*.
# 5. Calculate the proportion of the passengers that survived by *travel class* and *sex*. Present your results in *a single histogram*.
# 6. Create 2 equally populated *age categories* and calculate survival proportions by *age category*, *travel class* and *sex*. Present your results in a `DataFrame` with unique index.

# %%
# Write your answer here
